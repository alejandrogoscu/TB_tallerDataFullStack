# %%
# Conexion google cloud

from sqlalchemy import create_engine
import pandas as pd

# %%
# !pip install mysqlclient
# Out:
# Collecting mysqlclient
#   Downloading mysqlclient-2.2.7-cp311-cp311-win_amd64.whl.metadata (4.8 kB)
# Downloading mysqlclient-2.2.7-cp311-cp311-win_amd64.whl (207 kB)
# Installing collected packages: mysqlclient
# Successfully installed mysqlclient-2.2.7

# %%
conexion = "mysql://root:mysql@35.205.167.175:3306/escuelas"
engine = create_engine(conexion)

# %%
df = pd.read_csv("centros-educativos-en-valencia.csv", sep=";" )
df
# Out:
#                                    Geo Point  \
# 0    39.50261499907377, -0.41316999999999976
# 1      39.5302359990736, -0.3807020000000016
# 2    39.45169899907408, -0.37516600000000083
# 3     39.47401799907396, -0.3823219999999999
# 4     39.47543999907394, -0.3713410000000003
# ..                                       ...
# 529  39.48093999907391, -0.35487599999999997
# 530  39.45861799907405, -0.40538200000000024
# 531   39.48667399907386, -0.3945380000000012
# 532   39.43629299907419, -0.3964560000000006
# 533   39.47612999907393, -0.3816880000000005
#
#                                              Geo Shape    codcen  \
# 0    {"coordinates": [-0.41317, 39.50261499907377],...  46002301
# 1    {"coordinates": [-0.380702, 39.5302359990736],...  46009009
# 2    {"coordinates": [-0.375166, 39.45169899907408]...  46009368
# 3    {"coordinates": [-0.382322, 39.47401799907396]...  46009371
# 4    {"coordinates": [-0.371341, 39.47543999907394]...  46009526
# ..                                                 ...       ...
# 529  {"coordinates": [-0.354876, 39.48093999907391]...  46036992
# 530  {"coordinates": [-0.405382, 39.45861799907405]...  46037005
# 531  {"coordinates": [-0.394538, 39.48667399907386]...  46037121
# 532  {"coordinates": [-0.396456, 39.43629299907419]...  46037145
# 533  {"coordinates": [-0.381688, 39.47612999907393]...  46037236
#
#                                                 dlibre  \
# 0            CENTRE PRIVAT NATIVIDAD DE NUESTRA SEÑORA
# 1                           CEIP MANUEL GONZÁLEZ MARTÍ
# 2                          CENTRE PRIVAT MARTÍ SOROLLA
# 3                          CENTRE PRIVAT ESCUELAS PÍAS
# 4        CENTRE PRIVAT ESCOLANÍA NTRA.SRA.DESAMPARADOS
# ..                                                 ...
# 529  CENTRE ENSENYAMENTS ESPORTIUS C.F. DE JUDO Y D.A.
# 530                    CENTRE PRIVAT FP MEDAC VALÈNCIA
# 531  CENTRE PRIVAT FP DE LA PROFESIÓN DE PANADERÍA ...
# 532                  ESCOLA PRIVADA DE MÚSICA SEDAJAZZ
# 533                     CENTRE ESTRANGER LABA VALENCIA
#
#                                             dgenerica_  \
# 0    CENTRE PRIVAT D'EDUCACIÓ INFANTIL, PRIMÀRIA I ...
# 1              COL·LEGI D'EDUCACIÓ INFANTIL I PRIMÀRIA
# 2         CENTRE PRIVAT D'EDUCACIÓ INFANTIL I PRIMÀRIA
# 3    CENTRE PRIVAT D'EDUCACIÓ INFANTIL, PRIMÀRIA I ...
# 4       CENTRE PRIVAT D'EDUCACIÓ PRIMÀRIA I SECUNDÀRIA
# ..                                                 ...
# 529         CENTRE AUTORITZAT D'ENSENYAMENTS ESPORTIUS
# 530     CENTRE PRIVAT FORMACIÓ PROFESSIONAL ESPECÍFICA
# 531     CENTRE PRIVAT FORMACIÓ PROFESSIONAL ESPECÍFICA
# 532                           ESCOLA PRIVADA DE MÚSICA
# 533                     CENTRE DOCENT PRIVAT ESTRANGER
#
#                                             despecific     regimen  \
# 0                          NATIVIDAD DE NUESTRA SEÑORA  CONCERTADO
# 1                                MANUEL GONZÁLEZ MARTÍ     PÚBLICO
# 2                                        MARTÍ SOROLLA  CONCERTADO
# 3                                        ESCUELAS PÍAS  CONCERTADO
# 4                      ESCOLANÍA NTRA.SRA.DESAMPARADOS  CONCERTADO
# ..                                                 ...         ...
# 529  CENTRO DE FORMACIÓN DE JUDO Y DISCIPLINAS ASOC...     PRIVADO
# 530                                     MEDAC VALÈNCIA     PRIVADO
# 531          DE LA PROFESIÓN DE PANADERÍA Y PASTELERÍA     PRIVADO
# 532                                           SEDAJAZZ     PRIVADO
# 533                                      LABA VALENCIA     PRIVADO
#
#                                   direccion  codpos municipio_ provincia_  \
# 0                          CL. ESPARTERO, 2   46100  Burjassot   València
# 1                   CL. ALQUERIA GILET, S/N   46016   València   València
# 2        CL. INGENIERO JOAQUÍN BENLLOCH, 45   46026   València   València
# 3                         CL. CARNICEROS, 6   46001   València   València
# 4                  CL. GOBERNADOR VIEJO, 23   46003   València   València
# ..                                      ...     ...        ...        ...
# 529  CL. DANIEL BALACIART(POL.ESPORT.BENIMA   46020   València   València
# 530                        CL. ARGENTERS, 4   46014   València   València
# 531                  AV. GENERAL AVILÉS, 32   46015   València   València
# 532                    ED. ALQUERIA COCA, 5   46017   València   València
# 533                           CL. QUART, 21   46001   València   València
#
#          telef        fax                                     mail
# 0    963635262  963634802                    natividad@planalfa.es
# 1    962566390  962566391                      46009009@edu.gva.es
# 2    963730103  963730150                 ftortosa@gruposorolla.es
# 3    963915800  963915876  colegio.sanjoaquin@escolapiosbetania.es
# 4    963918434          0                   valencia@escolania.org
# ..         ...        ...                                      ...
# 529  963920630          0                          adm@fvaljudo.es
# 530  963219999          0                        valencia@medac.es
# 531  963918280          0                  secretaria@fegreppa.com
# 532  963765655          0                         info@sedajazz.es
# 533  963924919          0                 contact@labavalencia.net
#
# [534 rows x 14 columns]

# %%
df["Geo Shape"]
# Out:
# 0      {"coordinates": [-0.41317, 39.50261499907377],...
# 1      {"coordinates": [-0.380702, 39.5302359990736],...
# 2      {"coordinates": [-0.375166, 39.45169899907408]...
# 3      {"coordinates": [-0.382322, 39.47401799907396]...
# 4      {"coordinates": [-0.371341, 39.47543999907394]...
#                              ...
# 529    {"coordinates": [-0.354876, 39.48093999907391]...
# 530    {"coordinates": [-0.405382, 39.45861799907405]...
# 531    {"coordinates": [-0.394538, 39.48667399907386]...
# 532    {"coordinates": [-0.396456, 39.43629299907419]...
# 533    {"coordinates": [-0.381688, 39.47612999907393]...
# Name: Geo Shape, Length: 534, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 534 entries, 0 to 533
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Geo Point   534 non-null    object
#  1   Geo Shape   534 non-null    object
#  2   codcen      534 non-null    int64
#  3   dlibre      534 non-null    object
#  4   dgenerica_  534 non-null    object
#  5   despecific  529 non-null    object
#  6   regimen     534 non-null    object
#  7   direccion   534 non-null    object
#  8   codpos      534 non-null    int64
#  9   municipio_  534 non-null    object
#  10  provincia_  534 non-null    object
#  11  telef       534 non-null    int64
#  12  fax         534 non-null    int64
#  13  mail        534 non-null    object
# dtypes: int64(4), object(10)
# memory usage: 58.5+ KB

# %%
df2 = df.drop(["Geo Shape", "fax", "despecific","dgenerica_"],axis=1)
df2
# Out:
#                                    Geo Point    codcen  \
# 0    39.50261499907377, -0.41316999999999976  46002301
# 1      39.5302359990736, -0.3807020000000016  46009009
# 2    39.45169899907408, -0.37516600000000083  46009368
# 3     39.47401799907396, -0.3823219999999999  46009371
# 4     39.47543999907394, -0.3713410000000003  46009526
# ..                                       ...       ...
# 529  39.48093999907391, -0.35487599999999997  46036992
# 530  39.45861799907405, -0.40538200000000024  46037005
# 531   39.48667399907386, -0.3945380000000012  46037121
# 532   39.43629299907419, -0.3964560000000006  46037145
# 533   39.47612999907393, -0.3816880000000005  46037236
#
#                                                 dlibre     regimen  \
# 0            CENTRE PRIVAT NATIVIDAD DE NUESTRA SEÑORA  CONCERTADO
# 1                           CEIP MANUEL GONZÁLEZ MARTÍ     PÚBLICO
# 2                          CENTRE PRIVAT MARTÍ SOROLLA  CONCERTADO
# 3                          CENTRE PRIVAT ESCUELAS PÍAS  CONCERTADO
# 4        CENTRE PRIVAT ESCOLANÍA NTRA.SRA.DESAMPARADOS  CONCERTADO
# ..                                                 ...         ...
# 529  CENTRE ENSENYAMENTS ESPORTIUS C.F. DE JUDO Y D.A.     PRIVADO
# 530                    CENTRE PRIVAT FP MEDAC VALÈNCIA     PRIVADO
# 531  CENTRE PRIVAT FP DE LA PROFESIÓN DE PANADERÍA ...     PRIVADO
# 532                  ESCOLA PRIVADA DE MÚSICA SEDAJAZZ     PRIVADO
# 533                     CENTRE ESTRANGER LABA VALENCIA     PRIVADO
#
#                                   direccion  codpos municipio_ provincia_  \
# 0                          CL. ESPARTERO, 2   46100  Burjassot   València
# 1                   CL. ALQUERIA GILET, S/N   46016   València   València
# 2        CL. INGENIERO JOAQUÍN BENLLOCH, 45   46026   València   València
# 3                         CL. CARNICEROS, 6   46001   València   València
# 4                  CL. GOBERNADOR VIEJO, 23   46003   València   València
# ..                                      ...     ...        ...        ...
# 529  CL. DANIEL BALACIART(POL.ESPORT.BENIMA   46020   València   València
# 530                        CL. ARGENTERS, 4   46014   València   València
# 531                  AV. GENERAL AVILÉS, 32   46015   València   València
# 532                    ED. ALQUERIA COCA, 5   46017   València   València
# 533                           CL. QUART, 21   46001   València   València
#
#          telef                                     mail
# 0    963635262                    natividad@planalfa.es
# 1    962566390                      46009009@edu.gva.es
# 2    963730103                 ftortosa@gruposorolla.es
# 3    963915800  colegio.sanjoaquin@escolapiosbetania.es
# 4    963918434                   valencia@escolania.org
# ..         ...                                      ...
# 529  963920630                          adm@fvaljudo.es
# 530  963219999                        valencia@medac.es
# 531  963918280                  secretaria@fegreppa.com
# 532  963765655                         info@sedajazz.es
# 533  963924919                 contact@labavalencia.net
#
# [534 rows x 10 columns]

# %%
df2.columns = ['geo_point', 'codcen', 'nombre', 'regimen', 'direccion', 'CP',
        'municipio', 'provincia', 'telef', 'mail']

# %%
df2[["latitude","longitude"]] = df2["geo_point"].str.split(",", expand=True).astype(float)

df3 = df2.drop("geo_point",axis=1)
df3
# Out:
#        codcen                                             nombre     regimen  \
# 0    46002301          CENTRE PRIVAT NATIVIDAD DE NUESTRA SEÑORA  CONCERTADO
# 1    46009009                         CEIP MANUEL GONZÁLEZ MARTÍ     PÚBLICO
# 2    46009368                        CENTRE PRIVAT MARTÍ SOROLLA  CONCERTADO
# 3    46009371                        CENTRE PRIVAT ESCUELAS PÍAS  CONCERTADO
# 4    46009526      CENTRE PRIVAT ESCOLANÍA NTRA.SRA.DESAMPARADOS  CONCERTADO
# ..        ...                                                ...         ...
# 529  46036992  CENTRE ENSENYAMENTS ESPORTIUS C.F. DE JUDO Y D.A.     PRIVADO
# 530  46037005                    CENTRE PRIVAT FP MEDAC VALÈNCIA     PRIVADO
# 531  46037121  CENTRE PRIVAT FP DE LA PROFESIÓN DE PANADERÍA ...     PRIVADO
# 532  46037145                  ESCOLA PRIVADA DE MÚSICA SEDAJAZZ     PRIVADO
# 533  46037236                     CENTRE ESTRANGER LABA VALENCIA     PRIVADO
#
#                                   direccion     CP  municipio provincia  \
# 0                          CL. ESPARTERO, 2  46100  Burjassot  València
# 1                   CL. ALQUERIA GILET, S/N  46016   València  València
# 2        CL. INGENIERO JOAQUÍN BENLLOCH, 45  46026   València  València
# 3                         CL. CARNICEROS, 6  46001   València  València
# 4                  CL. GOBERNADOR VIEJO, 23  46003   València  València
# ..                                      ...    ...        ...       ...
# 529  CL. DANIEL BALACIART(POL.ESPORT.BENIMA  46020   València  València
# 530                        CL. ARGENTERS, 4  46014   València  València
# 531                  AV. GENERAL AVILÉS, 32  46015   València  València
# 532                    ED. ALQUERIA COCA, 5  46017   València  València
# 533                           CL. QUART, 21  46001   València  València
#
#          telef                                     mail   latitude  longitude
# 0    963635262                    natividad@planalfa.es  39.502615  -0.413170
# 1    962566390                      46009009@edu.gva.es  39.530236  -0.380702
# 2    963730103                 ftortosa@gruposorolla.es  39.451699  -0.375166
# 3    963915800  colegio.sanjoaquin@escolapiosbetania.es  39.474018  -0.382322
# 4    963918434                   valencia@escolania.org  39.475440  -0.371341
# ..         ...                                      ...        ...        ...
# 529  963920630                          adm@fvaljudo.es  39.480940  -0.354876
# 530  963219999                        valencia@medac.es  39.458618  -0.405382
# 531  963918280                  secretaria@fegreppa.com  39.486674  -0.394538
# 532  963765655                         info@sedajazz.es  39.436293  -0.396456
# 533  963924919                 contact@labavalencia.net  39.476130  -0.381688
#
# [534 rows x 11 columns]

# %%
df3.to_sql('colegios', con=engine, if_exists = 'append',index=False)
# Out:
# 534

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
API_URL = "https://router.huggingface.co/together/v1/chat/completions"
    
token = os.getenv("HUGGINGFACE_TOKEN")
token
# Out:
# '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'

# %%
import streamlit as st
from streamlit_folium import st_folium
import folium
import pandas as pd
import requests
from folium.plugins import MarkerCluster
import plotly.express as px
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# 2025-06-18 09:12:50.645 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# True
